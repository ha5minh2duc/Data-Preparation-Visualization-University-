# %%
import pandas as pd

# %% [markdown]
# Read the earthquakes.csv file and do the following tasks:
# 1. How many earthquake have magType 'ml' and type 'explosion'?
# 2. Calculate the mean of mag in Alaska and the distance is smaller than 100km, example: "62km W of Cantwell, Alaska".
# 3. Calculate the mean of mag in each quarter (q1:m1-m3, q2: m4-m6, q3: m7-m9, q4: m10-12), the "time" field stores the milliseconds from 1/1/1970, hint: timestamp.

# %%
df = pd.read_csv('earthquakes.csv', sep=',')
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
# ...

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %% [markdown]
# ### 1. How many earthquake have magType 'ml' and type 'explosion'?

# %%
len(df[(df.magType=='ml') & (df.type=='explosion')])
# Out:
# 79

# %% [markdown]
# ### 2. Calculate the mean of mag in Alaska and the distance is smaller than 100km, example: "62km W of Cantwell, Alaska".

# %%
# Alaska's earthquakes
alaska_earq = df.title.str.contains('Alaska')
df[alaska_earq].head()
# Out:
#    alert  cdi      code                                             detail  \
# 6    NaN  NaN  20280432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 18   NaN  NaN  20280424  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 21   NaN  NaN  20280421  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 26   NaN  NaN  20280415  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 27   NaN  NaN  20280412  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#     dmin  felt  gap                      ids  mag magType  ...     status  \
# 6    NaN   NaN  NaN             ,ak20280432,  1.7      ml  ...  automatic
# 18   NaN   NaN  NaN             ,ak20280424,  2.0      ml  ...  automatic
# 21   NaN   NaN  NaN             ,ak20280421,  1.7      ml  ...  automatic
# 26   NaN   NaN  NaN  ,ak20280415,us1000hbta,  2.8      ml  ...  automatic
# 27   NaN   NaN  NaN             ,ak20280412,  1.1      ml  ...  automatic
#
# ...

# %%
# Mean of mag in Alaska
df[alaska_earq].mag.mean()
# Out:
# 1.4655525238744929

# %%
# Calculate the distance < 100km in Alaska 
info = df[alaska_earq].title.str.split(" ", expand=True)  # extract the distance
distance = distance[info[3].str.rstrip("km").str.len() < 3]
df.iloc[distance.index].head()
# Out:
#    alert  cdi      code                                             detail  \
# 18   NaN  NaN  20280424  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 21   NaN  NaN  20280421  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 27   NaN  NaN  20280412  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 28   NaN  NaN  20280407  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 31   NaN  NaN  20280403  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#     dmin  felt  gap           ids  mag magType  ...     status           time  \
# 18   NaN   NaN  NaN  ,ak20280424,  2.0      ml  ...  automatic  1539468687232
# 21   NaN   NaN  NaN  ,ak20280421,  1.7      ml  ...  automatic  1539467905609
# 27   NaN   NaN  NaN  ,ak20280412,  1.1      ml  ...  automatic  1539465520462
# 28   NaN   NaN  NaN  ,ak20280407,  1.8      ml  ...  automatic  1539464607849
# 31   NaN   NaN  NaN  ,ak20280403,  2.3      ml  ...  automatic  1539462724148
#
# ...

# %% [markdown]
# ### 3. Calculate the mean of mag in each quarter (q1:m1-m3, q2: m4-m6, q3: m7-m9, q4: m10-12), the "time" field stores the milliseconds from 1/1/1970

# %%
# convert data in the "time" field into real time (ms)
df.quarter = pd.to_datetime(df.time, unit='ms')
df.quarter
# Out:
# 0      2018-10-13 23:59:28.010
# 1      2018-10-13 23:58:49.610
# 2      2018-10-13 23:57:42.610
# 3      2018-10-13 23:56:18.070
# 4      2018-10-13 23:51:56.050
#                  ...
# 9327   2018-09-18 00:23:48.060
# 9328   2018-09-18 00:22:15.130
# 9329   2018-09-18 00:18:28.180
# 9330   2018-09-18 00:12:25.350
# 9331   2018-09-18 00:01:04.470
# Name: quarter, Length: 9332, dtype: datetime64[ns]

# %%
# determine the quarter
df.quarter.dt.quarter
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 9327    3
# 9328    3
# 9329    3
# 9330    3
# 9331    3
# Name: quarter, Length: 9332, dtype: int64

# %%
# Result
df.groupby(df.quarter.dt.quarter).agg({'mag':'mean'})
# Out:
#               mag
# quarter
# 3        1.466735
# 4        1.536045
